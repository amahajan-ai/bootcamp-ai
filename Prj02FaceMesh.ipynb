# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.35-py3-none-win_amd64.whl.metadata (9.8 kB)
# Collecting absl-py~=2.3 (from mediapipe)
#   Using cached absl_py-2.5.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from mediapipe) (2024.12.14)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from mediapipe) (2.0.1)
# Collecting sounddevice~=0.5 (from mediapipe)
#   Using cached sounddevice-0.5.5-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: flatbuffers~=25.9 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from mediapipe) (25.12.19)
# Collecting opencv-contrib-python (from mediapipe)
#   Using cached opencv_contrib_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from mediapipe) (3.10.0)
# Requirement already satisfied: cffi in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from sounddevice~=0.5->mediapipe) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from matplotlib->mediapipe) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from matplotlib->mediapipe) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\envs\nielitai\lib\site-packages (from cffi->sounddevice~=0.5->mediapipe) (2.21)
# Using cached mediapipe-0.10.35-py3-none-win_amd64.whl (10.9 MB)
# Using cached absl_py-2.5.0-py3-none-any.whl (137 kB)
# Using cached sounddevice-0.5.5-py3-none-win_amd64.whl (365 kB)
# Using cached opencv_contrib_python-5.0.0.93-cp37-abi3-win_amd64.whl (53.8 MB)
# Installing collected packages: opencv-contrib-python, absl-py, sounddevice, mediapipe
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 2.1.0
#     Uninstalling absl-py-2.1.0:
#       Successfully uninstalled absl-py-2.1.0
# Successfully installed absl-py-2.5.0 mediapipe-0.10.35 opencv-contrib-python-5.0.0.93 sounddevice-0.5.5

# %%
import cv2
import mediapipe as mp

# Load OpenCV's built-in face detector
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

cap = cv2.VideoCapture(0)

while cap.isOpened():
  success, frame = cap.read()
  if not success:
    break

  # Convert frame to grayscale for detection
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

  # Detect faces
  faces = face_cascade.detectMultiScale(
      gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)
  )

  # Draw rectangle around detected faces
  for x, y, w, h in faces:
    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

  cv2.imshow('BCA AI Demo - Face Detection', frame)

  if cv2.waitKey(1) & 0xFF == ord('q'):
    break

cap.release()
cv2.destroyAllWindows()
